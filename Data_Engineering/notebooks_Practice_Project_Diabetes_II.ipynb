# %% [markdown]
# # Foundations of Data Science Project - Diabetes Analysis
#
# ---------------
# ## Context
# ---------------
#
# Diabetes is one of the most frequent diseases worldwide and the number of diabetic patients are growing over the years. The main cause of diabetes remains unknown, yet scientists believe that both genetic factors and environmental lifestyle play a major role in diabetes.
#
# A few years ago research was done on a tribe in America which is called the Pima tribe (also known as the Pima Indians). In this tribe, it was found that the ladies are prone to diabetes very early. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients were females at least 21 years old of Pima Indian heritage.
#
# -----------------
# ## Objective
# -----------------
#
# Here, we are analyzing different aspects of Diabetes in the Pima Indians tribe by doing Exploratory Data Analysis.
#
# -------------------------
# ## Data Dictionary
# -------------------------
#
# The dataset has the following information:
#
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: A function which scores likelihood of diabetes based on family history.
# * Age: Age in years
# * Outcome : Class variable (0: person is not diabetic or 1: person is diabetic)

# %% [markdown]
# ## Q 1: Import the necessary libraries and briefly explain the use of each library.

# %%
#remove _____ & write the appropriate library name

import numpy as np
import pandas as pd
import piplite
await piplite.install('seaborn')
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# # Ans 1:
#
#
# numpy (np): numpy is a powerful library for numerical computing in Python. It provides support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays efficiently.
#
# pandas (pd): pandas is a popular library for data manipulation and analysis. It provides data structures like DataFrames, which allow you to organize and manipulate structured data easily. It also offers functions for reading and writing data from various file formats, such as CSV, Excel, and SQL databases.
#
# piplite: It seems that there is no widely known library named "piplite."
#
# seaborn: seaborn is a data visualization library built on top of matplotlib. It provides a high-level interface for creating attractive and informative statistical graphics. Seaborn simplifies the process of creating visualizations such as scatter plots, bar plots, histograms, and more.
#
# matplotlib.pyplot (plt): matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. The pyplot module provides a simple interface for creating plots, graphs, and figures. It offers a wide range of customization options for creating publication-quality visualizations.

# %% [markdown]
# ## Q 2: Read the given dataset

# %%
#remove _____ & write the appropriate function name

pima = pd.read_csv("diabetes.csv")
pima
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ## Q3. Show the last 10 records of the dataset. How many columns are there?

# %%
#remove ______ and write the appropriate number in the function

pima.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 3:
# ten columns.
# The method tail() is used to display the last few rows of the DataFrame. In this case, frame.tail(10) would display the last ten rows of the DataFrame called frame.

# %% [markdown]
# ## Q4. Show the first 10 records of the dataset.

# %%
#remove _____ & write the appropriate function name and the number of rows to get in the output

pima.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %% [markdown]
# ## Q5. What do you understand by the dimension of the dataset? Find the dimension of the `pima` dataframe.

# %%
#remove _____ & write the appropriate function name
pima.shape
# Out:
# (768, 9)

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 5: the pima dataframe has 768 rows and 9 columns.

# %% [markdown]
# ## Q6. What do you understand by the size of the dataset? Find the size of the `pima` dataframe.

# %%
#remove _____ & write the appropriate function name

pima.size
# Out:
# 6912

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 6:total numbers of elements in rows and columns

# %% [markdown]
# ## Q7. What are the data types of all the variables in the data set?

# %%
#remove _____ & write the appropriate function name

pima.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 7:To determine the data types of variables in a dataset. all dataset is numercal of integer type but two of there is float types.

# %% [markdown]
# ## Q8. What do you mean by missing values? Are there any missing values in the `pima` dataframe?

# %%
#remove _____ & write the appropriate function name

pima.isnull().values.any()
# Out:
# False

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 8:Missing values refer to the absence or lack of data for one or more variables in a dataset./ no dont have missing value

# %% [markdown]
# ## Q9. What does summary statistics of data represents? Find the summary statistics for all variables except 'Outcome' in the `pima` data? Take one column/variable from the output table and explain all the statistical measures.

# %%
#remove _____ & write the appropriate function name

pima.iloc[:,0:8].describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    31.992578                  0.471876   33.240885
# std      7.884160                  0.331329   11.760232
# min      0.000000                  0.078000   21.000000
# ...

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 9:
# Count: The count value represents the number of non-missing or non-null values in the "Glucose" column. In this case, there are 768 data points with valid glucose measurements.
#
# Mean: The mean (or average) is the sum of all the values in the "Glucose" column divided by the count. It provides an indication of the central tendency of the data. In this case, the mean glucose level is approximately 120.89.
#
# Minimum (Min): The minimum value is the smallest observation in the "Glucose" column. It represents the lowest recorded glucose level in the dataset. In this case, the minimum glucose level is 0.

# %% [markdown]
# ## Q 10. Plot the distribution plot for the variable 'BloodPressure'. Write detailed observations from the plot. (2 Marks)

# %%
#remove _____ & write the appropriate library name

sns.displot(pima['BloodPressure'], kind='kde')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 10:
# The distribution plot shows the density estimation of the 'BloodPressure' variable.
# The x-axis represents the range of blood pressure values, while the y-axis represents the density or the likelihood of each value occurring.
# and the more blood pressure in 70
# The shape of the distribution indicates the overall pattern and variability of the blood pressure values.

# %% [markdown]
# ## Q 11. What is the 'BMI' for the person having the highest 'Glucose'?

# %%
#remove _____ & write the appropriate function name

pima[pima['Glucose'] == pima['Glucose'].idxmax()]['BMI']
# Out:
# Series([], Name: BMI, dtype: float64)

# %% [raw]
# Ans 11: maximum 'Glucose' value in the datase.

# %% [markdown]
# ## Q12.
# ### 12.1 What is the mean of the variable 'BMI'?
# ### 12.2 What is the median of the variable 'BMI'?
# ### 12.3 What is the mode of the variable 'BMI'?
# ### 12.4 Are the three measures of central tendency equal?

# %%
#remove _____ & write the appropriate function name

m1 = pima['BMI'].mean()  #Mean
print(m1)
m2 = pima['BMI'].median() #Median
print(m2)
m3 = pima['BMI'].mode()[0]  #Mode
print(m3)
# Out:
# 31.992578124999998
# 32.0
# 32.0

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 12:
# The appropriate function name for finding the mean of the variable 'BMI' is mean.
# The appropriate function name for finding the median of the variable 'BMI' is median.
# The appropriate function name for finding the mode of the variable 'BMI' is mode.
# The three measures of central tendency, mean, median, and mode, are not necessarily equal.
#
# The mean is the average value, the median is the middle value when the data is arranged in order, and the mode is the most frequently occurring value. These measures can be different depending on the distribution of the data.

# %% [markdown]
# ## Q13. How many women's 'Glucose' level is above the mean level of 'Glucose'?

# %%
#remove _____ & write the appropriate function name

pima[pima['Glucose'] > pima['Glucose'].mean()].shape[0]
# Out:
# 349

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 13: The comparison operator > is used to check which values in the 'Glucose' column are above the mean, and shape[0] gives the number of rows in the resulting dataframe where this condition is true.

# %% [markdown]
# ## Q14. How many women have their 'BloodPressure' equal to the median of 'BloodPressure' and their 'BMI' less than the median of 'BMI'?

# %%
#remove _____ & write the appropriate column name

#pima[(pima['BloodPressure']==pima['BloodPressure'].median()) & (pima['BMI']<pima['BMI'].median())]

median_blood_pressure = pima['BloodPressure'].median()
median_bmi = pima['BMI'].median()

women_count = len(pima[(pima['BloodPressure'] == median_blood_pressure) & (pima['BMI'] < median_bmi) & (pima['Outcome'] == 0)])
women_count
# Out:
# 16

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 14:
# in the output count of women we have Blood Pressure equal the median of blood pressure and BMI less than median of BMI
# The additional condition (pima['Outcome'] == 0) ensures that only women are considered (assuming '0' represents women in the 'Outcome' column).

# %% [markdown]
# ## Q15. Create the pairplot for variables 'Glucose', 'SkinThickness' and 'DiabetesPedigreeFunction'. Write you observations from the plot. (4 Marks)

# %%
## Q15. Create the pairplot for variables 'Glucose', 'SkinThickness' and 'DiabetesPedigreeFunction'. Write you observations from the plot. (4 Marks)
#remove _____ & write the appropriate function name

sns.pairplot(data=pima, vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 15:
# Scatter plots: You can observe the scatter plots between the variables. Each scatter plot represents the relationship between two variables. Look for any visible patterns or trends.
#
# Distributions: The diagonal of the pairplot shows the distribution of each variable. Examine the shape and spread of the distributions for 'Glucose', 'SkinThickness', and 'DiabetesPedigreeFunction'.
#
# Outcome differentiation: The points in the scatter plots are differentiated by color based on the 'Outcome' variable. Look for any noticeable patterns or clusters that indicate a relationship between the variables and the outcome of diabetes.
#
# Correlation: You can also assess the correlation between the variables by examining the overall trends in the scatter plots. Positive correlations may indicate that an increase in one variable corresponds to an increase in another, while negative correlations suggest an inverse relationship.

# %% [markdown]
# ## Q16. Plot the scatterplot between 'Glucose' and 'Insulin'. Write your observations from the plot.

# %%
## Q16. Plot the scatterplot between 'Glucose' and 'Insulin'. Write your observations from the plot. 
#remove _____ & write the appropriate function name

sns.scatterplot(x='Glucose', y='Insulin', data=pima)
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 16:
#
# Positive correlation: If the points on the scatterplot tend to form an upward-sloping pattern, it indicates a positive correlation between 'Glucose' and 'Insulin'. This means that as the levels of glucose increase, the levels of insulin also tend to increase.
#
# Negative correlation: If the points on the scatterplot tend to form a downward-sloping pattern, it indicates a negative correlation between 'Glucose' and 'Insulin'. This means that as the levels of glucose increase, the levels of insulin tend to decrease.
#
# No correlation: If the points on the scatterplot appear randomly scattered with no clear pattern, it indicates no significant correlation between 'Glucose' and 'Insulin'. This means that the levels of glucose do not have a strong influence on the levels of insulin, or vice versa.

# %% [markdown]
# ## Q 17. Plot the boxplot for the 'Age' variable. Are there outliers?

# %%
## Q 17. Plot the boxplot for the 'Age' variable. Are there outliers? 
#remove _____ & write the appropriate function and column name 


Plot the boxplot for the 'Age' variable. Are there outliers? 
plt.boxplot(pima['Age'])

plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()

explain the boxplot

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 17:
#
#
# The box plot illustrates the distribution of age. The age is represented on the vertical axis
# The box plot reveals the variation in ages.
# The median age is 28. This means that 50% of the individuals in the dataset are younger than 28 and 50% are older than 28.
# the boxplot indicating that most individuals fall between the ages of 25 and 40.
# suggesting that the dataset is skewed towards younger ages
#
#  The whiskers extend from the box to the minimum and maximum values within a certain range. Since there is an outlier above, the upper whisker extends only up to the maximum value within that range. In this case, the maximum age is 65.
#
# There is an outlier above the upper whisker, indicating at least one individual with an age higher than the typical range. The outlier represents an extreme value that stands out from the rest of the ages.

# %% [markdown]
# ## Q18. Plot histograms for variable Age to understand the number of women in different Age groups given that they have diabetes or not. Explain both histograms and compare them.

# %%
#remove _____ & write the appropriate function and column name
plt.hist(pima[pima['Outcome']==1]['Age'], bins = 5)
plt.title('Distribution of Age for Women who has Diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#remove _____ & write the appropriate function and column name

plt.hist(pima[pima['Outcome']==0]['Age'], bins = 5)
plt.title('Distribution of Age for Women who do not have Diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 18:
#
# Histogram 2 has a higher total frequency compared to Histogram 1. This indicates that Histogram 2 represents a larger sample size or more data points compared to Histogram 1.
#
# Histogram 1: The highest frequency is in the age range 20-30 (95), followed by 30-40 (75). The frequencies gradually decrease as the age ranges increase.
# Histogram 2: The highest frequency is in the age range 20-30 (340), followed by 30-40 (100). The frequencies decrease as the age ranges increase, but the drop is more significant compared to Histogram 1.
#
# Histogram 2 generally has higher frequencies in each age range compared to Histogram 1. This suggests a higher concentration or more occurrences of data points in Histogram 2.

# %% [markdown]
# ## Q 19. What is Inter Quartile Range of all the variables? Why is it used? Which plot visualizes the same?

# %%
#remove _____ & write the appropriate variable name

Q1 = pima.quantile(0.25)
Q3 = pima.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Pregnancies                   5.0000
# Glucose                      41.2500
# BloodPressure                18.0000
# SkinThickness                32.0000
# Insulin                     127.2500
# BMI                           9.3000
# DiabetesPedigreeFunction      0.3825
# Age                          17.0000
# Outcome                       1.0000
# dtype: float64

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 19:
#
# The Interquartile Range (IQR) is a statistical measure that represents the range between the first quartile (Q1) and the third quartile (Q3) of a dataset. It is calculated by subtracting Q1 from Q3: IQR = Q3 - Q1.
#
# The IQR is used to measure the spread or variability of a dataset. It provides information about the dispersion of the middle 50% of the data, excluding the lowest 25% (Q1) and the highest 25% (Q3) of the data. By focusing on this middle range, the IQR is less sensitive to extreme values or outliers in the dataset.
#
# In the given code snippet, the IQR is calculated for each variable in the "pima" dataset. The resulting IQR values represent the range between the 25th percentile (Q1) and the 75th percentile (Q3) for each variable.
#
# To visualize the IQR, a box plot (also known as a box-and-whisker plot) is commonly used. A box plot displays the IQR as a box, with the median represented by a line inside the box. The whiskers extend from the box to the minimum and maximum values within a certain range, typically 1.5 times the IQR. Any data points beyond the whiskers are considered outliers and are plotted individually. Box plots provide a compact visual summary of the distribution of a dataset, including its central tendency and spread.

# %% [markdown]
# ## Q 20. Find and visualize the the correlation matrix. Write your observations from the plot.

# %%
#remove _____ & write the appropriate function name and run the code

corr_matrix = pima.iloc[:,0:8].corr()

corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# ...

# %%
#remove _____ & write the appropriate function name

plt.figure(figsize=(8,8))
sns.heatmap(corr_matrix, annot = True)

# display the plot
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 20:
#
# correlation matrix shows various weak to moderate positive and negative correlations between the variables. The strongest correlation is observed between 'Age' and 'Pregnancies', indicating a relatively stronger relationship. However, further analysis is needed to determine the significance and potential causal relationships between these variables.

# %% [markdown]
# **Reference**: Foundation of Data Science, MIT Data Science And Machine Learning: Making Data Driven Decisions
