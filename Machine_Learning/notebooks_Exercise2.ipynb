# %% [markdown]
# ## Import labriry

# %%
import piplite
await piplite.install('seaborn')

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
from sklearn.compose import ColumnTransformer
await piplite.install('seaborn')
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Get the iris dataset

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %% [markdown]
# ### creata pd dataframes

# %%
# Creating pd DataFrames
iris_df = pd.DataFrame(data= iris.data, columns= iris.feature_names)
target_df = pd.DataFrame(data= iris.target, columns= ['species'])
def converter(specie):
    if specie == 0:
        return 'setosa'
    elif specie == 1:
        return 'versicolor'
    else:
        return 'virginica'
target_df['species'] = target_df['species'].apply(converter)
# Concatenate the DataFrames
iris_df = pd.concat([iris_df, target_df], axis= 1)

# %% [markdown]
# ### Describe the dataset

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# ### pairplot for iris dataset

# %%
sns.pairplot(iris_df, hue= 'species')

# %%
data = load_iris() 
data.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %% [markdown]
# ### data basically refere to the values in the independent columns

# %%
X = data.data 
X.shape
# Out:
# (150, 4)

# %% [markdown]
#  ### collecting the number represatation of the independent values

# %%
y = y.reshape(-1, 1)
y.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 y = y.reshape(-1, 1)
#       2 y.shape
#
# NameError: name 'y' is not defined

# %% [markdown]
#  ###  collecting the number represatation of the independent values

# %%
y = data.target 
y.shape
# Out:
# (150,)

# %% [markdown]
# ### combar between Pelat and sepal length in Irid dataset

# %%
plt.figure(figsize=(18,8),dpi=100)   #set the canvas size for visibility

plt.scatter(X.T[0],X.T[2])   #over here I use the T ndarray method to transpose the data then get columns at index 0 and 2
plt.title('IRIS Petal and sepal length', fontsize=20) # set the title of the plot and adjust my font size for readability

#then we set the label (just to be obvious)

plt.ylabel('Petal Length') 
plt.xlabel('sepal length')
# Out:
# Text(0.5, 0, 'sepal length')

# %% [markdown]
# ### display the first 5 rows

# %%
iris_df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
 pipeline= Pipeline([
    ("fill_nan_values", SimpleImputer())
])

# %%
pipeline.fit_transform(X,y)
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
pd.DataFrame(pipeline.fit_transform, columns=iris_df.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-ed1a42eada19> in ?()
# ----> 1 pd.DataFrame(pipeline.fit_transform, columns=iris_df.columns)
#
# /lib/python3.11/site-packages/pandas/core/frame.py in ?(self, data, index, columns, dtype, copy)
#     777                 )
#     778         # For data is scalar
#     779         else:
#     780             if index is None or columns is None:
# --> 781                 raise ValueError("DataFrame constructor not properly called!")
#     782
#     783             index = ensure_index(index)
#     784             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!
